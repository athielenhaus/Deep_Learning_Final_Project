# %% [markdown]
# # Predicting Pawpularity

# %% [markdown]
# #### Objective
# PetFinder.my is Malaysia’s leading animal welfare platform, featuring over 180,000 animals with 54,000 happily adopted. PetFinder collaborates closely with animal lovers, media, corporations, and global organizations to improve animal welfare.
#
# Currently, PetFinder.my uses a basic Cuteness Meter to rank pet photos. It analyzes picture composition and other factors compared to the performance of thousands of pet profiles. While this basic tool is helpful, it's still in an experimental stage and the algorithm could be improved.
#
# In this competition, you’ll analyze raw images and metadata to predict the “Pawpularity” of pet photos. You'll train and test your model on PetFinder.my's thousands of pet profiles.
#
# #### Description of data
# - CSV file with 9912 rows and 14 columns of metadata (no nulls)
# - Folder with 9912 jpeg files linked to metadata via id in file name
#
# #### Issues:
# - Selection method of data is unclear
# - Unclear whether photos are profile photos
# - Pawpularity score is based on webtraffic on pet profile, not based on metadata
#
# Noise
# - Metadata does not include information whether featured pets are dog or cat
# - Metadata does not include information about pet location

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/arnet/Desktop/Ironhack/Final_Project/petfinder-pawpularity-score/train.csv')

# %%
data.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72

# %%
data = data.set_index('Id')
data = data.rename_axis(None)

# %%
data.head()
# Out:
#                                   Subject Focus  Eyes  Face  Near  Action  \
# 0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#                                   Accessory  Group  Collage  Human  Occlusion  \
# 0007de18844b0dbbb5e1f607da0606e0          0      1        0      0          0
# 0009c66b9439883ba2750fb825e1d7db          0      0        0      0          0
# 0013fd999caf9a3efe1352ca1b0d937e          0      0        0      1          1
# 0018df346ac9c1d8413cfcc888ca8246          0      0        0      0          0
# 001dc955e10590d3ca4673f034feeef2          0      1        0      0          0
#
#                                   Info  Blur  Pawpularity
# 0007de18844b0dbbb5e1f607da0606e0     0     0           63
# 0009c66b9439883ba2750fb825e1d7db     0     0           42
# 0013fd999caf9a3efe1352ca1b0d937e     0     0           28
# 0018df346ac9c1d8413cfcc888ca8246     0     0           15
# 001dc955e10590d3ca4673f034feeef2     0     0           72

# %% [markdown]
# ## Process metadata

# %% [markdown]
# ### Scale pawpularity score (ALSO TRY WITHOUT SCALING)

# %%
# get target score
y = data["Pawpularity"]

# %%
# Scale and ensure that score is between 0 and 1
maxScore = y.max()
y_scaled= y / maxScore

# %%
y_scaled
# Out:
# 0007de18844b0dbbb5e1f607da0606e0    0.63
# 0009c66b9439883ba2750fb825e1d7db    0.42
# 0013fd999caf9a3efe1352ca1b0d937e    0.28
# 0018df346ac9c1d8413cfcc888ca8246    0.15
# 001dc955e10590d3ca4673f034feeef2    0.72
#                                     ...
# ffbfa0383c34dc513c95560d6e1fdb57    0.15
# ffcc8532d76436fc79e50eb2e5238e45    0.70
# ffdf2e8673a1da6fb80342fa3b119a20    0.20
# fff19e2ce11718548fa1c5d039a5192a    0.20
# fff8e47c766799c9e12f3cb3d66ad228    0.30
# Name: Pawpularity, Length: 9912, dtype: float64

# %%
# Drop 'y'
data = data.drop('Pawpularity', axis=1)
data.head()
# Out:
#                                   Subject Focus  Eyes  Face  Near  Action  \
# 0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#                                   Accessory  Group  Collage  Human  Occlusion  \
# 0007de18844b0dbbb5e1f607da0606e0          0      1        0      0          0
# 0009c66b9439883ba2750fb825e1d7db          0      0        0      0          0
# 0013fd999caf9a3efe1352ca1b0d937e          0      0        0      1          1
# 0018df346ac9c1d8413cfcc888ca8246          0      0        0      0          0
# 001dc955e10590d3ca4673f034feeef2          0      1        0      0          0
#
#                                   Info  Blur
# 0007de18844b0dbbb5e1f607da0606e0     0     0
# 0009c66b9439883ba2750fb825e1d7db     0     0
# 0013fd999caf9a3efe1352ca1b0d937e     0     0
# 0018df346ac9c1d8413cfcc888ca8246     0     0
# 001dc955e10590d3ca4673f034feeef2     0     0

# %%
data
# Out:
#                                   Subject Focus  Eyes  Face  Near  Action  \
# 0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
# ...                                         ...   ...   ...   ...     ...
# ffbfa0383c34dc513c95560d6e1fdb57              0     0     0     1       0
# ffcc8532d76436fc79e50eb2e5238e45              0     1     1     1       0
# ffdf2e8673a1da6fb80342fa3b119a20              0     1     1     1       0
# fff19e2ce11718548fa1c5d039a5192a              0     1     1     1       0
# fff8e47c766799c9e12f3cb3d66ad228              0     1     1     1       0
#
#                                   Accessory  Group  Collage  Human  Occlusion  \
# 0007de18844b0dbbb5e1f607da0606e0          0      1        0      0          0
# 0009c66b9439883ba2750fb825e1d7db          0      0        0      0          0
# 0013fd999caf9a3efe1352ca1b0d937e          0      0        0      1          1
# 0018df346ac9c1d8413cfcc888ca8246          0      0        0      0          0
# 001dc955e10590d3ca4673f034feeef2          0      1        0      0          0
# ...                                     ...    ...      ...    ...        ...
# ffbfa0383c34dc513c95560d6e1fdb57          0      0        0      0          0
# ffcc8532d76436fc79e50eb2e5238e45          0      0        0      0          0
# ffdf2e8673a1da6fb80342fa3b119a20          0      0        0      1          1
# fff19e2ce11718548fa1c5d039a5192a          0      0        0      1          0
# fff8e47c766799c9e12f3cb3d66ad228          0      0        0      0          0
#
#                                   Info  Blur
# 0007de18844b0dbbb5e1f607da0606e0     0     0
# 0009c66b9439883ba2750fb825e1d7db     0     0
# 0013fd999caf9a3efe1352ca1b0d937e     0     0
# 0018df346ac9c1d8413cfcc888ca8246     0     0
# 001dc955e10590d3ca4673f034feeef2     0     0
# ...                                ...   ...
# ffbfa0383c34dc513c95560d6e1fdb57     0     1
# ffcc8532d76436fc79e50eb2e5238e45     0     0
# ffdf2e8673a1da6fb80342fa3b119a20     0     0
# fff19e2ce11718548fa1c5d039a5192a     0     0
# fff8e47c766799c9e12f3cb3d66ad228     0     0
#
# [9912 rows x 12 columns]

# %% [markdown]
# ## Load image data

# %%
import cv2
import os
import numpy as np

# %%
def load_house_images(data, inputPath):
    # initialize our images array (i.e., the pet images themselves)
    images = []
   
    # get image files based on index column in dataframe
    for i in data.index.values:
        base = os.path.join(inputPath, i).replace('\\','/')
        basePath = f'{base}.jpg'
        #basePaths.append(f'{basePath}.jpg')
        image = cv2.imread(basePath)
        image = cv2.resize(image, (64, 64)) # best image size?
        images.append(image)
    
    # return our set of images
    return np.array(images)

# %%
inputPath = '/Users/arnet/Desktop/Ironhack/Final_Project/petfinder-pawpularity-score/train'

# make input path the current directory
os.chdir(inputPath)

images = load_house_images(data, inputPath)

# %%
# scale image size
images = images / 255.0

# %%
len(images)
# Out:
# 9912

# %%
type(images)
# Out:
# numpy.ndarray

# %%
images[0]
# Out:
# array([[[0.76078431, 0.70588235, 0.72156863],
#         [0.69803922, 0.64313725, 0.65882353],
#         [0.78431373, 0.73333333, 0.7372549 ],
#         ...,
#         [0.69411765, 0.69019608, 0.69803922],
#         [0.72941176, 0.73333333, 0.7254902 ],
#         [0.74901961, 0.74117647, 0.7372549 ]],
#
#        [[0.75294118, 0.70588235, 0.69803922],
#         [0.8       , 0.75294118, 0.74509804],
#         [0.77647059, 0.72941176, 0.72156863],
#         ...,
#         [0.56078431, 0.65882353, 0.6       ],
#         [0.56470588, 0.62352941, 0.58039216],
#         [0.59607843, 0.61960784, 0.59607843]],
#
#        [[0.7254902 , 0.67843137, 0.67058824],
#         [0.74509804, 0.69803922, 0.69019608],
#         [0.7372549 , 0.69019608, 0.68235294],
#         ...,
#         [0.57647059, 0.54509804, 0.54509804],
#         [0.59215686, 0.57647059, 0.58431373],
#         [0.52941176, 0.54117647, 0.54509804]],
#
#        ...,
#
#        [[0.63137255, 0.63529412, 0.61568627],
#         [0.55686275, 0.61176471, 0.62352941],
#         [0.41960784, 0.45882353, 0.45490196],
#         ...,
#         [0.69019608, 0.71372549, 0.71372549],
#         [0.68627451, 0.71764706, 0.74117647],
#         [0.71764706, 0.73333333, 0.76078431]],
#
#        [[0.54117647, 0.58823529, 0.58039216],
#         [0.56078431, 0.63137255, 0.58823529],
#         [0.49803922, 0.56862745, 0.50196078],
#         ...,
#         [0.72156863, 0.72941176, 0.73333333],
#         [0.70980392, 0.70588235, 0.69803922],
#         [0.7372549 , 0.74509804, 0.75294118]],
#
#        [[0.55686275, 0.57254902, 0.58823529],
#         [0.72156863, 0.72156863, 0.73333333],
#         [0.64313725, 0.62745098, 0.62352941],
#         ...,
#         [0.61960784, 0.63529412, 0.63921569],
#         [0.75686275, 0.77254902, 0.77647059],
#         [0.74509804, 0.76078431, 0.76470588]]])

# %% [markdown]
# ## Split into train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
# Split data for METADATA, IMAGES AND PREDICTION VALUE 'y'
split = train_test_split(data, images, y, test_size=0.25, random_state=42)
(X_train, X_test, XImages_train, XImages_test, y_train, y_test) = split

# %%
X_train
# Out:
#                                   Subject Focus  Eyes  Face  Near  Action  \
# 5e1a107f1f714592cd96d3e1329cab27              0     1     1     1       0
# e8d7c28145cfbdd2349acd8f2a28949f              0     1     1     0       0
# 20ebe45894e740a627da088335f9ddea              0     0     0     0       0
# 7c041fd9ed4c83ac88a3e9e0487a02ec              0     1     1     1       0
# 803bb1db4f00079a0be91f3319de78f9              0     1     1     1       0
# ...                                         ...   ...   ...   ...     ...
# 94773ee6f04891c99bc4d37e8f20ff6f              0     1     1     1       0
# 85e7146eeb13644b1bac74b684ccf51f              0     1     1     1       0
# 8afb263d779be24c94f01046e5ec3e81              0     1     1     1       0
# 15bda3335526d2ab18834c65f93add56              0     1     1     1       0
# bb263c3f1605cd5688a6fd1626f62466              0     1     1     1       0
#
#                                   Accessory  Group  Collage  Human  Occlusion  \
# 5e1a107f1f714592cd96d3e1329cab27          0      0        0      0          0
# e8d7c28145cfbdd2349acd8f2a28949f          0      0        1      0          1
# 20ebe45894e740a627da088335f9ddea          0      1        0      0          0
# 7c041fd9ed4c83ac88a3e9e0487a02ec          0      0        0      1          0
# 803bb1db4f00079a0be91f3319de78f9          0      0        0      0          0
# ...                                     ...    ...      ...    ...        ...
# 94773ee6f04891c99bc4d37e8f20ff6f          0      0        0      1          1
# 85e7146eeb13644b1bac74b684ccf51f          0      0        0      0          0
# 8afb263d779be24c94f01046e5ec3e81          0      0        0      0          0
# 15bda3335526d2ab18834c65f93add56          0      0        0      1          0
# bb263c3f1605cd5688a6fd1626f62466          0      1        0      0          0
#
#                                   Info  Blur
# 5e1a107f1f714592cd96d3e1329cab27     0     0
# e8d7c28145cfbdd2349acd8f2a28949f     1     0
# 20ebe45894e740a627da088335f9ddea     0     0
# 7c041fd9ed4c83ac88a3e9e0487a02ec     0     0
# 803bb1db4f00079a0be91f3319de78f9     0     0
# ...                                ...   ...
# 94773ee6f04891c99bc4d37e8f20ff6f     0     0
# 85e7146eeb13644b1bac74b684ccf51f     0     0
# 8afb263d779be24c94f01046e5ec3e81     0     0
# 15bda3335526d2ab18834c65f93add56     0     0
# bb263c3f1605cd5688a6fd1626f62466     0     0
#
# [7434 rows x 12 columns]

# %% [markdown]
# ## Create model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
import tensorflow as tf

# %% [markdown]
# ### Mixed model

# %%
# MLP model FOR METADATA
def create_mlp(dim, regress=False):
    # define our MLP network
    model = Sequential()
    model.add(Dense(8, input_dim=dim, activation="relu"))
    model.add(Dense(4, activation="relu"))
    # check to see if the regression node should be added
    if regress:
        model.add(Dense(1, activation="linear"))
    # return our model
    return model

# %%
# CNN for regression prediction FOR IMAGE DATA
def create_cnn(width, height, depth, filters=(16, 32, 64), regress=False):
    # initialize the input shape and channel dimension, assuming
    # TensorFlow/channels-last ordering
    inputShape = (height, width, depth)
    chanDim = -1

    # define the model input
    inputs = Input(shape=inputShape)
    # loop over the number of filters
    for (i, f) in enumerate(filters):
        # if this is the first CONV layer then set the input
        # appropriately
        if i == 0:
            x = inputs
        # CONV => RELU => BN => POOL
        x = Conv2D(f, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=chanDim)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
            # flatten the volume, then FC => RELU => BN => DROPOUT
    x = Flatten()(x)
    x = Dense(16)(x)
    x = Activation("relu")(x)
    x = BatchNormalization(axis=chanDim)(x)
    x = Dropout(0.5)(x)
    # apply another FC layer, this one to match the number of nodes
    # coming out of the MLP
    x = Dense(4)(x)
    x = Activation("relu")(x)
    # check to see if the regression node should be added
    if regress:
        x = Dense(1, activation="linear")(x)
    # construct the CNN
    model = Model(inputs, x)
    # return the CNN
    return model

# %%
# import the necessary packages
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import concatenate
import numpy as np
import os

# %%
# CREATE the MLP and CNN models
mlp = create_mlp(X_train.shape[1], regress=False) # X_train.shape[1] = number of METADATA columns i.e. inputs
cnn = create_cnn(64, 64, 3, regress=False)

# create the input to our final set of layers as the *output* of both
# the MLP and CNN
combinedInput = concatenate([mlp.output, cnn.output])

# our final FC layer head will have two dense layers, the final one
# being our regression head
x = Dense(4, activation="relu")(combinedInput)
x = Dense(1, activation="linear")(x)

# our final model will accept categorical/numerical data on the MLP
# input and images on the CNN input, outputting a single value (the
# predicted price of the house)
model = Model(inputs=[mlp.input, cnn.input], outputs=x)

# %%
##### compile the model using mean absolute percentage error as our loss,
# implying that we seek to minimize the absolute percentage difference
# between our price *predictions* and the *actual prices*
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mse", 
              metrics = ['mse', 
                         'mean_absolute_error',
                         'mean_absolute_percentage_error',
                        tf.keras.metrics.RootMeanSquaredError()],
              optimizer='adam')
# train the model
print("[INFO] training model...")
model.fit(
    x=[X_train, XImages_train], y=y_train,
    validation_data=([X_test, XImages_test], y_test),
    epochs=5, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/5
# 930/930 [==============================] - 82s 88ms/step - loss: 855.0894 - mse: 855.0894 - mean_absolute_error: 22.0981 - mean_absolute_percentage_error: 79.2989 - root_mean_squared_error: 29.2419 - val_loss: 514.2081 - val_mse: 514.2081 - val_mean_absolute_error: 16.2368 - val_mean_absolute_percentage_error: 70.3946 - val_root_mean_squared_error: 22.6762
# Epoch 2/5
# 930/930 [==============================] - 81s 88ms/step - loss: 455.6855 - mse: 455.6855 - mean_absolute_error: 15.9587 - mean_absolute_percentage_error: 78.7366 - root_mean_squared_error: 21.3468 - val_loss: 483.5132 - val_mse: 483.5132 - val_mean_absolute_error: 15.9766 - val_mean_absolute_percentage_error: 73.2309 - val_root_mean_squared_error: 21.9889
# Epoch 3/5
# 930/930 [==============================] - 90s 97ms/step - loss: 444.3948 - mse: 444.3948 - mean_absolute_error: 15.7219 - mean_absolute_percentage_error: 78.0850 - root_mean_squared_error: 21.0807 - val_loss: 471.8547 - val_mse: 471.8547 - val_mean_absolute_error: 16.5595 - val_mean_absolute_percentage_error: 82.6017 - val_root_mean_squared_error: 21.7222
# Epoch 4/5
# 930/930 [==============================] - 82s 88ms/step - loss: 440.2243 - mse: 440.2243 - mean_absolute_error: 15.7104 - mean_absolute_percentage_error: 78.8975 - root_mean_squared_error: 20.9815 - val_loss: 476.3222 - val_mse: 476.3222 - val_mean_absolute_error: 15.7946 - val_mean_absolute_percentage_error: 72.6247 - val_root_mean_squared_error: 21.8248
# Epoch 5/5
# 930/930 [==============================] - 88s 95ms/step - loss: 434.7082 - mse: 434.7082 - mean_absolute_error: 15.5484 - mean_absolute_percentage_error: 78.4160 - root_mean_squared_error: 20.8497 - val_loss: 469.7184 - val_mse: 469.7184 - val_mean_absolute_error: 15.7648 - val_mean_absolute_percentage_error: 73.3875 - val_root_mean_squared_error: 21.6730: 0s - loss: 435.2690 - mse: 435.2690 - mean_absolute_error: 15.5629 - mean_absolute_percentage_error: 78.4681 - root_mean_squared_error: 2

# %%
# make predictions on the testing data
print("[INFO] predicting house prices...")
preds = model.predict([testAttrX, testImagesX])

# %% [markdown]
# [INFO] training model...
# Epoch 1/5
# 930/930 [==============================] - 75s 80ms/step - loss: 65.1758 - val_loss: 56.7548
# Epoch 2/5
# 930/930 [==============================] - 95s 102ms/step - loss: 57.6539 - val_loss: 56.2901
# Epoch 3/5
# 930/930 [==============================] - 77s 82ms/step - loss: 57.4500 - val_loss: 56.4440
# Epoch 4/5
# 930/930 [==============================] - 75s 80ms/step - loss: 57.4485 - val_loss: 56.5238
# Epoch 5/5
# 930/930 [==============================] - 77s 83ms/step - loss: 57.4599 - val_loss: 56.1432

# %%
# create our Convolutional Neural Network FOR IMAGES and then compile the model
# using mean absolute percentage error as our loss, implying that we
# seek to minimize the absolute percentage difference between our
# price *predictions* and the *actual prices*
model = create_cnn(64, 64, 3, regress=True)
#opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", 
              optimizer='adam', 
              metrics=['mse', tf.metrics.RootMeanSquaredError()])

# %%
# train the model
print("[INFO] training model...")
model.fit(x=X_train, y=y_train, 
    validation_data=(X_test, y_test),
    epochs=5, batch_size=8)
# Out:
# [INFO] training model...
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 64, 64, 3) for input Tensor("input_2:0", shape=(None, 64, 64, 3), dtype=float32), but it was called on an input with incompatible shape (None, 12).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16972/3842264164.py in <module>
#       1 # train the model
#       2 print("[INFO] training model...")
# ----> 3 model.fit(x=X_train, y=y_train,
#       4     validation_data=(X_test, y_test),
#       5     epochs=5, batch_size=8)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     695     self._concrete_stateful_fn = (
# --> 696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     697             *args, **kwds))
#     698
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:806 train_function  *
#         return step_function(self, iterator)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:789 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:747 train_step
#         y_pred = self(x, training=True)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:985 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\functional.py:385 call
#         return self._run_internal_graph(
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\functional.py:508 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:975 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs,
#     C:\Users\arnet\anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:191 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer conv2d_3 is incompatible with the layer: : expected min_ndim=4, found ndim=2. Full shape received: [None, 12]

# %% [markdown]
# Note:
# * Metrics show no further improvements after 10 epochs
# * loss (Mean Absolute Percetage Error): 56.9354 - mse: 0.0626 - root_mean_squared_error: 0.2502 - val_loss: 57.6136 - val_mse: 0.0662 - val_root_mean_squared_error: 0.2573

# %%
# import the necessary packages
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
''' additional modules not used'''
import numpy as np
import os

# %% [markdown]
# ## Train model

# %%
# import the necessary packages
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
# import the necessary packages
from tensorflow.keras.optimizers import Adam
import numpy as np
import locale
import os

# %%
# function for creating SEQUENTIAL model
def create_mlp(dim, regress=False):
    # define our MLP network
    model = Sequential()
    model.add(Dense(8, input_dim=dim, activation="relu"))
    model.add(Dense(4, activation="relu"))
    # check to see if the regression node should be added
    if regress:
        model.add(Dense(1, activation="linear"))
    # return our model
    return model

# %%
X_train.shape[1]
# Out:
# 12

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7434 entries, 8462 to 9771
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Subject Focus  7434 non-null   int64
#  1   Eyes           7434 non-null   int64
#  2   Face           7434 non-null   int64
#  3   Near           7434 non-null   int64
#  4   Action         7434 non-null   int64
#  5   Accessory      7434 non-null   int64
#  6   Group          7434 non-null   int64
#  7   Collage        7434 non-null   int64
#  8   Human          7434 non-null   int64
#  9   Occlusion      7434 non-null   int64
#  10  Info           7434 non-null   int64
#  11  Blur           7434 non-null   int64
# dtypes: int64(12)
# memory usage: 755.0 KB

# %%
import math
epox = 100
b_size = math.floor(7434 / epox)
b_size
# Out:
# 74

# %%
from tensorflow.keras import metrics
# create our MLP and then compile the model using mean absolute
# percentage error as our loss, implying that we seek to minimize
# the absolute percentage difference between our price *predictions*
# and the *actual prices*
model = create_mlp(X_train.shape[1], regress=True)
opt = Adam(lr=1e-3, decay=1e-3 / 200) # decay is unclear
model.compile(loss="mean_absolute_percentage_error", 
              optimizer=opt,
              metrics = ['mse', tf.metrics.RootMeanSquaredError()] # added metrics
             ) 
# train the model
print("[INFO] training model...")
model.fit(x=X_train, y=y_train, 
    validation_data=(X_test, y_test),
    epochs=epox)
#batch_size=b_size)
# Out:
# [INFO] training model...
# Epoch 1/100
# 233/233 [==============================] - 0s 2ms/step - loss: 105.3474 - mse: 0.2009 - root_mean_squared_error: 0.4483 - val_loss: 60.2439 - val_mse: 0.0703 - val_root_mean_squared_error: 0.2652
# Epoch 2/100
# 233/233 [==============================] - 0s 1ms/step - loss: 59.0478 - mse: 0.0665 - root_mean_squared_error: 0.2579 - val_loss: 58.5227 - val_mse: 0.0672 - val_root_mean_squared_error: 0.2592
# Epoch 3/100
# 233/233 [==============================] - 0s 2ms/step - loss: 57.9493 - mse: 0.0641 - root_mean_squared_error: 0.2532 - val_loss: 58.0666 - val_mse: 0.0671 - val_root_mean_squared_error: 0.2591
# Epoch 4/100
# 233/233 [==============================] - 0s 1ms/step - loss: 57.5276 - mse: 0.0639 - root_mean_squared_error: 0.2527 - val_loss: 57.9113 - val_mse: 0.0690 - val_root_mean_squared_error: 0.2627
# Epoch 5/100
# 233/233 [==============================] - 0s 1ms/step - loss: 57.3862 - mse: 0.0646 - root_mean_squared_error: 0.2542 - val_loss: 57.7250 - val_mse: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 6/100
# 233/233 [==============================] - 0s 1ms/step - loss: 57.1812 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.6514 - val_mse: 0.0671 - val_root_mean_squared_error: 0.2591
# Epoch 7/100
# 233/233 [==============================] - 0s 1ms/step - loss: 57.0611 - mse: 0.0645 - root_mean_squared_error: 0.2539 - val_loss: 57.6485 - val_mse: 0.0640 - val_root_mean_squared_error: 0.2530
# Epoch 8/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.9916 - mse: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 57.6117 - val_mse: 0.0640 - val_root_mean_squared_error: 0.2529
# Epoch 9/100
# 233/233 [==============================] - ETA: 0s - loss: 55.7368 - mse: 0.0617 - root_mean_squared_error: 0.24 - 0s 1ms/step - loss: 56.8834 - mse: 0.0622 - root_mean_squared_error: 0.2493 - val_loss: 57.6251 - val_mse: 0.0673 - val_root_mean_squared_error: 0.2593
# Epoch 10/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.8338 - mse: 0.0633 - root_mean_squared_error: 0.2517 - val_loss: 57.5954 - val_mse: 0.0662 - val_root_mean_squared_error: 0.2574
# Epoch 11/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.8021 - mse: 0.0633 - root_mean_squared_error: 0.2516 - val_loss: 57.6213 - val_mse: 0.0675 - val_root_mean_squared_error: 0.2598
# Epoch 12/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.7921 - mse: 0.0636 - root_mean_squared_error: 0.2521 - val_loss: 57.6999 - val_mse: 0.0627 - val_root_mean_squared_error: 0.2504
# Epoch 13/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.7779 - mse: 0.0627 - root_mean_squared_error: 0.2504 - val_loss: 57.5962 - val_mse: 0.0651 - val_root_mean_squared_error: 0.2551
# Epoch 14/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.7158 - mse: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 57.5841 - val_mse: 0.0661 - val_root_mean_squared_error: 0.2571
# Epoch 15/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.6978 - mse: 0.0627 - root_mean_squared_error: 0.2504 - val_loss: 57.6178 - val_mse: 0.0663 - val_root_mean_squared_error: 0.2575
# Epoch 16/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.7327 - mse: 0.0636 - root_mean_squared_error: 0.2522 - val_loss: 57.7445 - val_mse: 0.0628 - val_root_mean_squared_error: 0.2507
# Epoch 17/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.5234 - mse: 0.0623 - root_mean_squared_error: 0.2497 - val_loss: 57.6073 - val_mse: 0.0667 - val_root_mean_squared_error: 0.2583
# Epoch 18/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.5627 - mse: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 57.6098 - val_mse: 0.0657 - val_root_mean_squared_error: 0.2563
# Epoch 19/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.6004 - mse: 0.0636 - root_mean_squared_error: 0.2523 - val_loss: 57.6422 - val_mse: 0.0635 - val_root_mean_squared_error: 0.2521
# Epoch 20/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.5860 - mse: 0.0627 - root_mean_squared_error: 0.2505 - val_loss: 57.6985 - val_mse: 0.0631 - val_root_mean_squared_error: 0.2511
# Epoch 21/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.5707 - mse: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 57.6466 - val_mse: 0.0653 - val_root_mean_squared_error: 0.2555
# Epoch 22/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4664 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.6574 - val_mse: 0.0672 - val_root_mean_squared_error: 0.2592
# Epoch 23/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4829 - mse: 0.0633 - root_mean_squared_error: 0.2516 - val_loss: 57.6196 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 24/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.5156 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.5968 - val_mse: 0.0658 - val_root_mean_squared_error: 0.2564
# Epoch 25/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.4946 - mse: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 57.6580 - val_mse: 0.0665 - val_root_mean_squared_error: 0.2579
# Epoch 26/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4598 - mse: 0.0633 - root_mean_squared_error: 0.2515 - val_loss: 57.6727 - val_mse: 0.0639 - val_root_mean_squared_error: 0.2527
# Epoch 27/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4208 - mse: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 57.6909 - val_mse: 0.0632 - val_root_mean_squared_error: 0.2514
# Epoch 28/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4447 - mse: 0.0628 - root_mean_squared_error: 0.2507 - val_loss: 57.6346 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 29/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.4056 - mse: 0.0629 - root_mean_squared_error: 0.2507 - val_loss: 57.7041 - val_mse: 0.0642 - val_root_mean_squared_error: 0.2534
# Epoch 30/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.3409 - mse: 0.0632 - root_mean_squared_error: 0.2515 - val_loss: 57.7122 - val_mse: 0.0629 - val_root_mean_squared_error: 0.2507
# Epoch 31/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.4147 - mse: 0.0627 - root_mean_squared_error: 0.2505 - val_loss: 57.5905 - val_mse: 0.0641 - val_root_mean_squared_error: 0.2531
# Epoch 32/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.2862 - mse: 0.0624 - root_mean_squared_error: 0.2498 - val_loss: 57.7041 - val_mse: 0.0653 - val_root_mean_squared_error: 0.2554
# Epoch 33/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.3426 - mse: 0.0637 - root_mean_squared_error: 0.2525 - val_loss: 57.6691 - val_mse: 0.0635 - val_root_mean_squared_error: 0.2519
# Epoch 34/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2889 - mse: 0.0626 - root_mean_squared_error: 0.2501 - val_loss: 57.6553 - val_mse: 0.0635 - val_root_mean_squared_error: 0.2519
# Epoch 35/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.2731 - mse: 0.0637 - root_mean_squared_error: 0.2524 - val_loss: 58.0271 - val_mse: 0.0604 - val_root_mean_squared_error: 0.2458
# Epoch 36/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2870 - mse: 0.0620 - root_mean_squared_error: 0.2490 - val_loss: 57.6793 - val_mse: 0.0659 - val_root_mean_squared_error: 0.2566
# Epoch 37/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2704 - mse: 0.0631 - root_mean_squared_error: 0.2513 - val_loss: 57.6763 - val_mse: 0.0651 - val_root_mean_squared_error: 0.2551
# Epoch 38/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1960 - mse: 0.0639 - root_mean_squared_error: 0.2529 - val_loss: 57.9363 - val_mse: 0.0606 - val_root_mean_squared_error: 0.2462
# Epoch 39/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.3155 - mse: 0.0621 - root_mean_squared_error: 0.2491 - val_loss: 57.7133 - val_mse: 0.0663 - val_root_mean_squared_error: 0.2574
# Epoch 40/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2029 - mse: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 57.6699 - val_mse: 0.0647 - val_root_mean_squared_error: 0.2544
# Epoch 41/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2343 - mse: 0.0630 - root_mean_squared_error: 0.2510 - val_loss: 57.6875 - val_mse: 0.0654 - val_root_mean_squared_error: 0.2557
# Epoch 42/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1226 - mse: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 57.7776 - val_mse: 0.0635 - val_root_mean_squared_error: 0.2521
# Epoch 43/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.0678 - mse: 0.0618 - root_mean_squared_error: 0.2485 - val_loss: 57.7472 - val_mse: 0.0684 - val_root_mean_squared_error: 0.2615
# Epoch 44/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2069 - mse: 0.0641 - root_mean_squared_error: 0.2532 - val_loss: 57.7759 - val_mse: 0.0633 - val_root_mean_squared_error: 0.2516
# Epoch 45/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1866 - mse: 0.0626 - root_mean_squared_error: 0.2501 - val_loss: 57.6198 - val_mse: 0.0662 - val_root_mean_squared_error: 0.2573
# Epoch 46/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.2221 - mse: 0.0633 - root_mean_squared_error: 0.2515 - val_loss: 57.6943 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2539
# Epoch 47/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1683 - mse: 0.0629 - root_mean_squared_error: 0.2507 - val_loss: 57.6501 - val_mse: 0.0654 - val_root_mean_squared_error: 0.2557
# Epoch 48/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1725 - mse: 0.0628 - root_mean_squared_error: 0.2507 - val_loss: 57.7373 - val_mse: 0.0667 - val_root_mean_squared_error: 0.2583
# Epoch 49/100
# 233/233 [==============================] - 0s 1ms/step - loss: 56.1180 - mse: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 57.7699 - val_mse: 0.0670 - val_root_mean_squared_error: 0.2588
# Epoch 50/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.1452 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.7707 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 51/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.1021 - mse: 0.0631 - root_mean_squared_error: 0.2513 - val_loss: 57.8069 - val_mse: 0.0641 - val_root_mean_squared_error: 0.2533
# Epoch 52/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0367 - mse: 0.0628 - root_mean_squared_error: 0.2507 - val_loss: 57.6579 - val_mse: 0.0659 - val_root_mean_squared_error: 0.2568
# Epoch 53/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0757 - mse: 0.0630 - root_mean_squared_error: 0.2510 - val_loss: 57.6674 - val_mse: 0.0652 - val_root_mean_squared_error: 0.2554
# Epoch 54/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0744 - mse: 0.0632 - root_mean_squared_error: 0.2513 - val_loss: 57.8328 - val_mse: 0.0626 - val_root_mean_squared_error: 0.2502
# Epoch 55/100
# 233/233 [==============================] - 1s 2ms/step - loss: 56.0638 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.7558 - val_mse: 0.0666 - val_root_mean_squared_error: 0.2581
# Epoch 56/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.1221 - mse: 0.0634 - root_mean_squared_error: 0.2518 - val_loss: 57.7995 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2545
# Epoch 57/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9936 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.8105 - val_mse: 0.0633 - val_root_mean_squared_error: 0.2515
# Epoch 58/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0073 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.8587 - val_mse: 0.0636 - val_root_mean_squared_error: 0.2522
# Epoch 59/100
# 233/233 [==============================] - 1s 2ms/step - loss: 56.0366 - mse: 0.0626 - root_mean_squared_error: 0.2503 - val_loss: 57.6481 - val_mse: 0.0639 - val_root_mean_squared_error: 0.2528
# Epoch 60/100
# 233/233 [==============================] - 1s 2ms/step - loss: 56.0750 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.7685 - val_mse: 0.0656 - val_root_mean_squared_error: 0.2561
# Epoch 61/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0138 - mse: 0.0638 - root_mean_squared_error: 0.2527 - val_loss: 58.0373 - val_mse: 0.0613 - val_root_mean_squared_error: 0.2475
# Epoch 62/100
# 233/233 [==============================] - 1s 3ms/step - loss: 56.0063 - mse: 0.0622 - root_mean_squared_error: 0.2495 - val_loss: 57.7578 - val_mse: 0.0653 - val_root_mean_squared_error: 0.2556
# Epoch 63/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9615 - mse: 0.0633 - root_mean_squared_error: 0.2515 - val_loss: 57.8319 - val_mse: 0.0629 - val_root_mean_squared_error: 0.2508
# Epoch 64/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9812 - mse: 0.0632 - root_mean_squared_error: 0.2513 - val_loss: 57.8005 - val_mse: 0.0638 - val_root_mean_squared_error: 0.2526
# Epoch 65/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.1205 - mse: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 57.7809 - val_mse: 0.0627 - val_root_mean_squared_error: 0.2503
# Epoch 66/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9963 - mse: 0.0625 - root_mean_squared_error: 0.2499 - val_loss: 57.5396 - val_mse: 0.0650 - val_root_mean_squared_error: 0.2549
# Epoch 67/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0498 - mse: 0.0630 - root_mean_squared_error: 0.2510 - val_loss: 57.7573 - val_mse: 0.0645 - val_root_mean_squared_error: 0.2540
# Epoch 68/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9853 - mse: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 57.9473 - val_mse: 0.0619 - val_root_mean_squared_error: 0.2489
# Epoch 69/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9494 - mse: 0.0626 - root_mean_squared_error: 0.2502 - val_loss: 57.8389 - val_mse: 0.0679 - val_root_mean_squared_error: 0.2606
# Epoch 70/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9572 - mse: 0.0639 - root_mean_squared_error: 0.2528 - val_loss: 57.8657 - val_mse: 0.0633 - val_root_mean_squared_error: 0.2517
# Epoch 71/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9574 - mse: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 57.8600 - val_mse: 0.0627 - val_root_mean_squared_error: 0.2505
# Epoch 72/100
# 233/233 [==============================] - ETA: 0s - loss: 56.1122 - mse: 0.0632 - root_mean_squared_error: 0.25 - 0s 2ms/step - loss: 56.0164 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.8567 - val_mse: 0.0630 - val_root_mean_squared_error: 0.2511
# Epoch 73/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9732 - mse: 0.0626 - root_mean_squared_error: 0.2502 - val_loss: 57.8964 - val_mse: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 74/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9433 - mse: 0.0637 - root_mean_squared_error: 0.2524 - val_loss: 58.0622 - val_mse: 0.0615 - val_root_mean_squared_error: 0.2479
# Epoch 75/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9839 - mse: 0.0630 - root_mean_squared_error: 0.2509 - val_loss: 57.8044 - val_mse: 0.0637 - val_root_mean_squared_error: 0.2523
# Epoch 76/100
# 233/233 [==============================] - 0s 2ms/step - loss: 56.0237 - mse: 0.0629 - root_mean_squared_error: 0.2507 - val_loss: 57.8685 - val_mse: 0.0636 - val_root_mean_squared_error: 0.2522
# Epoch 77/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9171 - mse: 0.0624 - root_mean_squared_error: 0.2497 - val_loss: 57.7565 - val_mse: 0.0648 - val_root_mean_squared_error: 0.2546
# Epoch 78/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9590 - mse: 0.0633 - root_mean_squared_error: 0.2517 - val_loss: 57.8848 - val_mse: 0.0641 - val_root_mean_squared_error: 0.2531
# Epoch 79/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8703 - mse: 0.0631 - root_mean_squared_error: 0.2511 - val_loss: 57.7754 - val_mse: 0.0625 - val_root_mean_squared_error: 0.2500
# Epoch 80/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9286 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.8843 - val_mse: 0.0640 - val_root_mean_squared_error: 0.2529
# Epoch 81/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9218 - mse: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 57.9306 - val_mse: 0.0666 - val_root_mean_squared_error: 0.2580
# Epoch 82/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9439 - mse: 0.0629 - root_mean_squared_error: 0.2508 - val_loss: 57.9450 - val_mse: 0.0631 - val_root_mean_squared_error: 0.2513
# Epoch 83/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8810 - mse: 0.0629 - root_mean_squared_error: 0.2509 - val_loss: 57.9411 - val_mse: 0.0643 - val_root_mean_squared_error: 0.2536
# Epoch 84/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8972 - mse: 0.0631 - root_mean_squared_error: 0.2513 - val_loss: 58.0829 - val_mse: 0.0627 - val_root_mean_squared_error: 0.2505
# Epoch 85/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8968 - mse: 0.0629 - root_mean_squared_error: 0.2509 - val_loss: 57.8823 - val_mse: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 86/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8226 - mse: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 57.9504 - val_mse: 0.0689 - val_root_mean_squared_error: 0.2626
# Epoch 87/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.9892 - mse: 0.0635 - root_mean_squared_error: 0.2519 - val_loss: 57.8172 - val_mse: 0.0636 - val_root_mean_squared_error: 0.2522
# Epoch 88/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8992 - mse: 0.0630 - root_mean_squared_error: 0.2509 - val_loss: 57.7856 - val_mse: 0.0653 - val_root_mean_squared_error: 0.2555
# Epoch 89/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8886 - mse: 0.0633 - root_mean_squared_error: 0.2516 - val_loss: 57.8104 - val_mse: 0.0651 - val_root_mean_squared_error: 0.2552
# Epoch 90/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8826 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.9674 - val_mse: 0.0635 - val_root_mean_squared_error: 0.2519
# Epoch 91/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8360 - mse: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 57.8753 - val_mse: 0.0638 - val_root_mean_squared_error: 0.2526
# Epoch 92/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8591 - mse: 0.0627 - root_mean_squared_error: 0.2505 - val_loss: 58.0739 - val_mse: 0.0692 - val_root_mean_squared_error: 0.2631
# Epoch 93/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8953 - mse: 0.0640 - root_mean_squared_error: 0.2530 - val_loss: 58.2127 - val_mse: 0.0616 - val_root_mean_squared_error: 0.2483
# Epoch 94/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8376 - mse: 0.0625 - root_mean_squared_error: 0.2500 - val_loss: 57.8386 - val_mse: 0.0661 - val_root_mean_squared_error: 0.2572
# Epoch 95/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8237 - mse: 0.0632 - root_mean_squared_error: 0.2514 - val_loss: 57.9359 - val_mse: 0.0634 - val_root_mean_squared_error: 0.2519
# Epoch 96/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8499 - mse: 0.0630 - root_mean_squared_error: 0.2511 - val_loss: 58.0132 - val_mse: 0.0660 - val_root_mean_squared_error: 0.2569
# Epoch 97/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8726 - mse: 0.0634 - root_mean_squared_error: 0.2519 - val_loss: 58.1314 - val_mse: 0.0622 - val_root_mean_squared_error: 0.2493
# Epoch 98/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8442 - mse: 0.0625 - root_mean_squared_error: 0.2499 - val_loss: 57.8062 - val_mse: 0.0664 - val_root_mean_squared_error: 0.2577
# Epoch 99/100
# 233/233 [==============================] - 0s 2ms/step - loss: 55.8283 - mse: 0.0635 - root_mean_squared_error: 0.2521 - val_loss: 58.1971 - val_mse: 0.0622 - val_root_mean_squared_error: 0.2495
# Epoch 100/100
# 233/233 [==============================] - 1s 3ms/step - loss: 55.8658 - mse: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 58.1472 - val_mse: 0.0630 - val_root_mean_squared_error: 0.2510

# %%
# make predictions on the testing data
print("[INFO] predicting house prices...")
preds = model.predict(X_test)
# compute the difference between the *predicted* house prices and the
# *actual* house prices, then compute the percentage difference and
# the absolute percentage difference
diff = preds.flatten() - y_test
percentDiff = (diff / y_test) * 100
absPercentDiff = np.abs(percentDiff)
# compute the mean and standard deviation of the absolute percentage
# difference
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
# finally, show some statistics on our model
print("[INFO] avg. house price: {}, std house price: {}".format(data["Pawpularity"].mean(), 
      data["Pawpularity"].std()))
print("[INFO] mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# [INFO] predicting house prices...
# [INFO] avg. house price: 38.03904358353511, std house price: 20.591990105774546
# [INFO] mean: 58.15%, std: 131.29%
